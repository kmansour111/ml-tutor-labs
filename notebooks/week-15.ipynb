# %% [markdown]
# # ML Tutor — Week 15: Open-source LLMs & AI coding tools
# **Track:** DL & GenAI · **Lab:** Lab 15 — Inspect an open model and verify AI-assisted code
#
# **Objectives this week:**
# 1. Run open models from Hugging Face: hub, transformers pipelines, model cards, licenses. *(CO5)*
# 2. Use agentic coding tools (Cowork, Codex/Claude Code, Copilot) critically and verify their output unaided. *(CO3)*
# 3. Decide open-source vs hosted AI for privacy, cost, and PHI constraints. *(CO3, CO6)*
#
# > Anti-shortcut rule: hints live in ML Tutor, revealed one tier at a time. Work here, check hints there. You are graded on unaided competence.

# %% [markdown]
# ## Before you start (~25 min)
# **Goal for this session:** Arrive ready to compare open-source and hosted AI tools without losing the privacy, license, and verification questions. This week is about using AI coding tools critically and knowing when not to. Reference delta: keep model-card and license checking core; deeper tool ecosystem coverage is optional.
#
# **Warm up — answer these from memory before scrolling on** (retrieval beats re-reading):
# 1. From Week 14, why does deployment still need monitoring and retraining?
# 2. What is one reason a shipped system still needs logging and evidence?
# 3. Why should tool choice in health settings include privacy and license questions?

# %%
# SETUP — run me first (Shift+Enter)
import numpy as np
import pandas as pd

# Dataset: Synthetic Hugging Face-style model card, license summary, and a small AI-assisted code snippet for verification. No PHI, no clinical use.
# PLACEHOLDER: the dataset for this week arrives with the course repo under data/week-15/ .
# If a lab step expects a file, download it from the ml-tutor-labs repo's data/week-15/ folder first.

print("Setup OK — numpy", np.__version__, "· pandas", pd.__version__)

# %% [markdown]
# ## Worked example — Open models versus hosted tools
# **Lane A · the general idea:** Open-source models are inspectable and often self-hostable, while hosted tools are managed by a provider. The tradeoffs include privacy, cost, control, and convenience.
#
# **Lane B · the same idea in pharmacy terms:** In a health-science setting, an open model may be preferable when privacy or local control matters more than convenience. The choice should be tied to the data and policy constraints.

# %% [markdown]
# ### Worked walkthrough (read-only) — how Lab Step 1 will go
# This week's first step doesn't suit a toy demo, so walk the starter code before you run it in the lab below:
#
# ```python
# # TODO: read the provided model card and license summary.
# model_card = ...
# license_text = ...
#
# # TODO: write down the key constraints
# notes = ...
# print(notes)
# ```
#
# **What to expect when you run it:** Checkpoint 1 verifies: the student identifies at least one intended use, one limitation, and one license-related consideration.
#
# Read each TODO and predict what you'll write BEFORE you scroll to the lab.

# %% [markdown]
# ## 1. Read the model card and license
# Inspect the open model’s intended use, limitations, and license before considering it for the task.
#
# **Checkpoint:** Checkpoint 1 verifies: the student identifies at least one intended use, one limitation, and one license-related consideration.

# %%
# TODO: read the provided model card and license summary.
model_card = ...
license_text = ...

# TODO: write down the key constraints
notes = ...
print(notes)

# %% [markdown]
# **Self-check 1:** run your cell, then compare its output against the checkpoint description above — does it satisfy *every* clause? Stuck? Graduated hints for this exact step live in **ML Tutor** (revealed one tier at a time, never the full answer). Fix, re-run, then move on.

# %% [markdown]
# ## 2. Compare open versus hosted choices
# State when you would prefer an open model and when a hosted tool might be acceptable or preferable.
#
# **Checkpoint:** Checkpoint 2 verifies: the student compares open and hosted choices using privacy, cost, and control as criteria.

# %%
comparison = """
...
"""

print(comparison)

# %% [markdown]
# **Self-check 2:** run your cell, then compare its output against the checkpoint description above — does it satisfy *every* clause? Stuck? Graduated hints for this exact step live in **ML Tutor** (revealed one tier at a time, never the full answer). Fix, re-run, then move on.

# %% [markdown]
# ## 3. Verify an AI-assisted code snippet
# Inspect a short AI-generated code snippet, test it mentally or in the notebook, and note any corrections.
#
# **Checkpoint:** Checkpoint 3 verifies: the student checks the code rather than trusting it and records at least one correction or test result.

# %%
# TODO: inspect and verify the snippet.
snippet = """
...
"""

verification_notes = ...
print(verification_notes)

# %% [markdown]
# **Self-check 3:** run your cell, then compare its output against the checkpoint description above — does it satisfy *every* clause? Stuck? Graduated hints for this exact step live in **ML Tutor** (revealed one tier at a time, never the full answer). Fix, re-run, then move on.

# %% [markdown]
# ## 4. Summarize the responsible-use rule
# Write a concise policy note for choosing and verifying AI tools in the course.
#
# **Checkpoint:** Checkpoint 4 verifies: the student explains a responsible-use rule in plain language and names one privacy or license constraint.

# %%
summary = """
...
"""

print(summary)

# %% [markdown]
# **Self-check 4:** run your cell, then compare its output against the checkpoint description above — does it satisfy *every* clause? Stuck? Graduated hints for this exact step live in **ML Tutor** (revealed one tier at a time, never the full answer). Fix, re-run, then move on.

# %% [markdown]
# ## Reflection — make it stick (5 min, write before you leave)
# 1. **Teach it:** explain your Step 4 code to a colleague in exactly 3 sentences — what goes in, what happens, what comes out. Write the sentences below.
# 2. **What would break this?** A classmate insists: *“Open-source automatically means safe or free to use everywhere.”* Using what you just built, describe one concrete case from this week's lab where acting on that belief produces a wrong result — and how you would catch it.

# %%
# Your reflection (write as comments)
# 1) Three sentences:
#
# 2) What would break this, concretely:
#

# %% [markdown]
# ## Optional challenge — Homework: Responsible tool-choice note
# Write a short note explaining when you would choose an open model over a hosted tool, what you would check before using it, and how you would verify any AI-assisted code it produced.
#
# **Deliverable:** A concise tool-choice note plus one verified code snippet or test note.

# %%
# HW / challenge workspace — build it here
