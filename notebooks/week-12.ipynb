# %% [markdown]
# # ML Tutor — Week 12: LLMs & GenAI, critically
# **Track:** DL & GenAI · **Lab:** Lab 12 — Verify AI output and protect the source
#
# **Objectives this week:**
# 1. Identify failure modes of commercial LLMs: hallucination, sycophancy, leakage. *(CO3)*
# 2. Design prompting and verification workflows that check AI output against sources. *(CO3, CO6)*
# 3. Apply data- and IP-protection practices when using AI tools in health settings. *(CO3)*
#
# > Anti-shortcut rule: hints live in ML Tutor, revealed one tier at a time. Work here, check hints there. You are graded on unaided competence.

# %% [markdown]
# **Dataset:** Synthetic source bundle for a teaching task, including a small approved corpus and a deliberately imperfect AI draft to verify. No PHI, no clinical advice.

# %% [markdown]
# ## 1. Inspect the AI draft and the source corpus
# Read the draft answer, read the approved sources, and mark the claims that need checking.
#
# **Checkpoint:** Checkpoint 1 verifies: the student can identify at least one unsupported claim and one supported claim in the draft.

# %%
# TODO: inspect the model draft and the approved sources.
draft_text = ...
source_texts = ...

# TODO: list unsupported claims
unsupported = ...
print(unsupported)

# %% [markdown]
# ## 2. Rewrite with grounded language
# Revise the answer so that every important claim is supported, cited, or refused.
#
# **Checkpoint:** Checkpoint 2 verifies: the revision removes unsupported claims and uses grounded wording or citations.

# %%
# TODO: write a grounded revision.
grounded_answer = """
...
"""

print(grounded_answer)

# %% [markdown]
# ## 3. Apply a data/IP protection check
# Decide whether anything in the workflow should have been redacted or protected before using an external model.
#
# **Checkpoint:** Checkpoint 3 verifies: the student can identify at least one protection concern and one safer handling step.

# %%
# TODO: describe any data or IP issues you noticed.
protection_notes = """
...
"""

print(protection_notes)

# %% [markdown]
# ## 4. Summarize the safe AI workflow
# Write a concise process note explaining how to use AI drafts safely in the course.
#
# **Checkpoint:** Checkpoint 4 verifies: the student can explain the safe workflow in plain language and name one verification rule they would keep using.

# %%
summary = """
...
"""

print(summary)

# %% [markdown]
# ## Homework — Safe-AI workflow memo
# Write a short memo describing how you would verify an AI draft, what you would refuse to trust, and one data-protection rule you would apply before using an external AI tool.
#
# **Deliverable:** A concise workflow memo plus one grounded rewrite example.

# %%
# HW workspace
